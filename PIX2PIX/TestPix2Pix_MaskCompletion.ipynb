# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd "/content/drive/MyDrive/Eyeglasses_Removal-main/PIX2PIX"
# Out:
# /content/drive/MyDrive/Eyeglasses_Removal-main/PIX2PIX

# %%
# !python3 Mask_completion.py
# Out:
# Call with args:
# Namespace(test_path='./input_masks', completion_model_path='./log/pix2pix_epoch17.pth', post_process=True, save_path='./completed_masks')
