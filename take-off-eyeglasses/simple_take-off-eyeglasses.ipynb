# %% [markdown]
# ONLY Test PIX2PIX

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Eyeglasses_Removal-main/take-off-eyeglasses
# Out:
# /content/drive/MyDrive/Eyeglasses_Removal-main/take-off-eyeglasses

# %%
# !python3 easy_use_proposed.py
# Out:
# Call with args:
# Namespace(input_dir='../TestDataAndResults/CelebA/with_glasses', completion_model_dir='../PIX2PIX/log/pix2pix_epoch17.pth', completion=True, post_process=True, save_dir='../TestDataAndResults/CelebA/removed_by_prop', img_size=256, ckpt_path='./ckpt/pretrained.pt')
